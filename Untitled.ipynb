# %%
from keras.models import Sequential # 케라스의 Sequential()을 임포트
from keras.layers import Dense # 케라스의 Dense()를 임포트
from keras import optimizers # 케라스의 옵티마이저를 임포트
import numpy as np # Numpy를 임포트
import pandas as pd

df = pd.read_hdf('h5data/roic_pcr_roe_pbr_values', key='df')

tdf1 = df['roic'].dropna()
tdf2 = df['pcr'].dropna()
tdf3 = df['roe'].dropna()
tdf4 = df['pbr'].dropna()
X=np.array([tdf1.index, tdf2.index, tdf3.index, tdf4.index]) # 공부하는 시간
y=targetdf.values.flatten() # 각 공부하는 시간에 맵핑되는 성적
print(X)
print(y)
model=Sequential()
model.add(Dense(4, input_shape=(4,), activation='linear'))
sgd=optimizers.SGD(lr=0.000000001)
# 학습률(learning rate, lr)은 0.01로 합니다.
model.compile(optimizer=sgd ,loss='mse',metrics=['mse'])
# 옵티마이저는 경사하강법의 일종인 확률적 경사 하강법 sgd를 사용합니다.
# 손실 함수(Loss function)은 평균제곱오차 mse를 사용합니다.
model.fit(X,y, batch_size=1, epochs=300, shuffle=True)
# Out:
# [  15   69   79 ... 1672 1696 1761]
# [ 3.31876607 -0.2176781  -0.19625247 ... -0.0537931   0.
#   0.00440529]
# Epoch 1/300
# 1061/1061 [==============================] - 2s 1ms/step - loss: 383161.9930 - mean_squared_error: 383161.9930
# Epoch 2/300
# 1061/1061 [==============================] - 1s 1ms/step - loss: 7057.3862 - mean_squared_error: 7057.3862TA: 0s - loss: 12992.0176 - mean_squared_e - ETA: 0s - loss: 8520.3611 - mean_squared_erro
# Epoch 3/300
# 1061/1061 [==============================] - 1s 1ms/step - loss: 131.9072 - mean_squared_error: 131.9072
# Epoch 4/300
# 1061/1061 [==============================] - 1s 1ms/step - loss: 4.5949 - mean_squared_error: 4.5949
# Epoch 5/300
# 1061/1061 [==============================] - 1s 1ms/step - loss: 2.2563 - mean_squared_error: 2.2563
# Epoch 6/300
# 1061/1061 [==============================] - 1s 1ms/step - loss: 2.2115 - mean_squared_error: 2.2115
# Epoch 7/300
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(X, model.predict(X), 'b', X,y, 'k.')
plt.show()

# %%
for layer in model.layers: print(layer.get_config(), layer.get_weights())
# Out:
# {'name': 'dense_2', 'trainable': True, 'batch_input_shape': (None, 1), 'dtype': 'float32', 'units': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None} [array([[0.00042485]], dtype=float32), array([-0.00109271], dtype=float32)]
